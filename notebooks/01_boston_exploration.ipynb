# %% [markdown]
# # Boston Exploration
#
# Use this notebook to explore data layers and sanity-check features.

# %%
import yaml, pandas as pd, geopandas as gpd
from spectral_urbanism.utils.io import load_yaml
cfg = load_yaml('../configs/boston.yaml')
cfg['city']
